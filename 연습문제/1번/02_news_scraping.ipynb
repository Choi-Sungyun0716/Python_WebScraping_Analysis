# %%
import requests
from bs4 import BeautifulSoup

#section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}

section_dict = {'기후/환경':'climate','사회':'society','경제':'economy','정치':'politics',
                '국제':'world','문화':'culture','생활':'life','IT/과학':'tech','인물':'people'}




def print_news(section):  #print_new(103,'생활/문화') 
    sid = section_dict[section]
    url = f'https://news.daum.net/{sid}'
    print(f'======> {url} {section} 뉴스 <======')

    req_header = {
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
    
    }

    res = requests.get(url, headers=req_header)
    res.encoding = 'utf-8'
   

    if(res.ok):
        html = res.text 
        #print(html)
        # BeautifulSoup 객체 생성  
        soup = BeautifulSoup(html, "html.parser")
        #print(soup)
        # CSS 선택자
        a_tags = soup.select("ul.list_newsheadline2 li ") 
        



        for li_tag in a_tags:
            if(li_tag.text):
                a_tag = li_tag.find('a')
                link = a_tag["href"]

                strong_tag = li_tag.select_one('div.cont_thumb strong.tit_txt')
                title = strong_tag.text
                
                print(link)
                print(title)
            
# 응답(response)이 Error 이면 status code 출력 
    else:
      print(f"Error Code = {res.status_code}")

# %%
print_news('경제')
print_news('사회')
# Out:
# ======> https://news.daum.net/economy 경제 뉴스 <======
# https://v.daum.net/v/20250723150154993
# 3선 딱지 뗀 '보험맨' 하태경 "암호화폐 융합보험 시대 곧 온다" [월간중앙]
# https://v.daum.net/v/20250723142101850
# 네일왕서 아파트왕으로...박화영 인코코 회장 “맨해튼서 예술같은 부동산개발”
# https://v.daum.net/v/20250723140906360
# [대전 둔산지구의 미래를 그리다] 디지털·스마트 신도시 '풍골'에서 미래도시의 청사진을 보다
# https://v.daum.net/v/20250723135926840
# "미일 협상, 중요한 참고사례…FTA 고려시 日보단 더 얻어야"
# https://v.daum.net/v/20250723130459121
# [충남창업人-톡](6)카데아, '3D 어라운드 뷰' 개발…美·유럽 시장 정조준
# https://v.daum.net/v/20250723125814945
# [뉴스나우] 이틀 앞으로 다가온 한미 협상 시사점은?
# https://v.daum.net/v/20250723122253422
# “대졸자, 일자리 밖에 서다”.. 비경제활동 300만 시대의 경고
# https://v.daum.net/v/20250723122213414
# 무료로 배송 받았던 카톡 선물 '유료' 옵션 생긴 이유는?
# https://v.daum.net/v/20250723120247911
# 혼인·출생아 수 청신호…예비부부 울리는 ‘스드메’
# ======> https://news.daum.net/society 사회 뉴스 <======
# https://v.daum.net/v/20250723155156616
# 61년 만에 고개 숙인 검찰… ‘강제 키스 혀 절단’ 사건 최말자 씨 ‘무죄 구형’ (종합)
# https://v.daum.net/v/20250723154812391
# 녹조 범벅 용인 기흥저수지에서 전국 조정 경기?
# https://v.daum.net/v/20250723153436675
# 계엄이면 선관위 점거 가능하다?… ‘내란군’ 변호인의 어불성설
# https://v.daum.net/v/20250723153301583
# 싱가포르 따라한 빅트리 논란에... 창원시, 의견수렴 나선다
# https://v.daum.net/v/20250723153140501
# 이창용 vs 김용범, 스테이블코인 누구 말이 옳을까 [이영태의 초점]
# https://v.daum.net/v/20250723152639253
# 차에 GPS 달고 드론 비행경로 조작…특검 ‘의도적 은폐’ 수사
# https://v.daum.net/v/20250723152116961
# 청년의 뿌리, 지역에 내리다…대구가톨릭대, RISE로 혁신 생태계 조성
# https://v.daum.net/v/20250723151904853
# 사립대학 구조개선 법적 근거 마련…AI교과서 당분간 지위 유지
# https://v.daum.net/v/20250723151728752
# LG•삼성•코웨이•중소기업 등 17개 기업 ‘2025 대한민국 올해의 녹색상품’ 수상
