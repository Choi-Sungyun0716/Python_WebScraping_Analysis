# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# requests 라이브러리 설치여부 확인
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.3
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# beautifulsoup4 라이브러리 설치여부 확인
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page: https://www.crummy.com/software/BeautifulSoup/bs4/
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert

# %%
# reqeusts, bs4 import
import requests 
import bs4
# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print(f'requests 버전 = {requests.__version__}')
print(f'bs4 버전 = {bs4.__version__}')
# Out:
# requests 버전 = 2.32.3
# bs4 버전 = 4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스 
req_param = {
    'sid': 105
}
#url = 'https://news.naver.com/section/105'

url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)

# 요청 헤더 설정 : 브라우저 정보
req_header = {
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
    
}

# requests 의 get() 함수 호출하기 
res = requests.get(url, headers=req_header)

print(res.status_code, res.ok) #200번대면 오류 없음
print(type(res))
print(res)

# 응답(response)이 OK 이면
# 응답 (response)에서 text 추출
if(res.ok):
    html = res.text 
    #print(html)
    # BeautifulSoup 객체 생성  
    soup = BeautifulSoup(html, "html.parser")
    #print(soup)
    # CSS 선택자
    a_tags = soup.select("div.sa_text a[href *='mnews/article'].sa_text_title ") 
    
    #print(type(a_tags))

    print(len(a_tags))

    for idx, a_tag in enumerate(a_tags, 1):
        if(a_tag.text):
            title = a_tag.text.strip()
            link = a_tag["href"]
            print(f"{idx} {title} : {link}")
            
# 응답(response)이 Error 이면 status code 출력 
else:
      print(f"Error Code = {res.status_code}")
# Out:
# https://news.naver.com/section/105
# 200 True
# <class 'requests.models.Response'>
# <Response [200]>
# 0

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

#section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}

section_dict = {'정치':100,'경제':101,'사회':102,'생활/문화':103,'세계':104,'IT/과학':105}



def print_news(section):  #print_new(103,'생활/문화') 
    sid = section_dict[section]
    url = f'https://news.naver.com/section/{sid}'
    print(f'{url} {section} 뉴스')

    req_header = {
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
    
    }

    res = requests.get(url, headers=req_header)

    print(res.status_code, res.ok) #200번대면 오류 없음

    if(res.ok):
        html = res.text 
        #print(html)
        # BeautifulSoup 객체 생성  
        soup = BeautifulSoup(html, "html.parser")
        print(soup)

        a_tags = soup.select("div.sa_text a[href *='mnews/article'].sa_text_title ") 
        print(len(a_tags))
    
        #print(type(a_tags))

        print(len(a_tags))

        for idx, a_tag in enumerate(a_tags, 1):
            if(a_tag.text):
                title = a_tag.text.strip()
                link = a_tag["href"]
                print(f"{idx} {title} : {link}")

    else:
      print(f"Error Code = {res.status_code}")

# %%
print_news('정치')
# Out:
# https://news.naver.com/section/100 정치 뉴스
# 200 True
# <!DOCTYPE html>
#
# <html data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport">
# <meta content="정치 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/section/100" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="정치 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" name="twitter:description"/>
# <title>정치 : 네이버 뉴스</title>
# <link href="https://static-nnews.pstatic.net/css/min/20250717/news.css" rel="stylesheet"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2023/08/21/favicon.ico" rel="shortcut icon" type="image/x-icon">
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" rel="apple-touch-icon-precomposed" size="72x72"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" rel="apple-touch-icon-precomposed" size="96x96"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" rel="apple-touch-icon-precomposed" size="144x144"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" rel="apple-touch-icon-precomposed" size="192x192"/>
# <script>
# 			var bSupportedIntersectionObserver = "IntersectionObserver" in window;
# 		</script>
# <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>
# <script>
# 			var g_ssc = nsc = "news.v3_sec";
# 			var g_default_area = "pol";
#
# 			var svr = "one-service-r-20250717-250717-162549-8dfcd689-z5vg6";
# 			var nelo = {
# 				name : "one-front",
# 				url : "https://kr-col-ext.nelo.navercorp.com/_store",
# 				sampleNumber : 100,
# 				maxCount : 100,
# 				maxSendMessage : "로그 전송 최대치 도달"
# 			};
# 			var isGreendot = document.cookie.indexOf("MM_NEW=1") > -1;
# 			var isNewGreendot = document.cookie.indexOf("MM_NEW=2") > -1;
# 			var domain = "https://n.news.naver.com";
# 			var ajaxDomain = "";
# 			var newsDomain = "";
# 			var layoutName = "section_home";
# 			var layoutType = "section";
# 			var isAvailableDarkMode = false;
# 			var moduleLoadStatus = -1;
#
# 			var article = {
#
# 				officeId: "",
# 				articleId: "",
# 				sectionId : "",
# 				gdid: "",
# 				type: "",
# 				sectionInfo: {
# 					firstSection: "",
# 					secondSection: "",
# 					thirdSection: ""
# 				},
# 				title: document.title
# 			};
#
#
#
# 			var office = {
# 				isChannel: false,
# 				isPressHome: false,
# 				name : "",
# 				category : ""
# 			};
#
# 			var searchQuery = (function() {
# 				var referrerLink = document.createElement("a");
# 				var emptySearch = "";
#
# 				referrerLink.href = document.referrer || "";
#
# 				if (referrerLink.host.indexOf("search.naver.com") === -1) {
# 					return emptySearch;
# 				}
#
# 				return decodeURIComponent(
# 					(
# 						referrerLink.search.match(/(?:\?|&)query\=([^&]+)/) || [ null, emptySearch ]
# 					)[1].replace(/\+/g, " ")
# 				);
# 			})();
#
# 			var divIds = [];
# 			var syncDivIds = [];
# 			var syncDivIdsForNonArticle = [];
#
# 			var unitIds = [];
# 			var syncUnitIds = [];
# 			var syncUnitIdsForNonArticle = [];
#
# 			window.gladsdk = window.gladsdk || { cmd: [] };
# 			gladsdk.cmd.push(function() {
# 				gladsdk.setGlobalConfig({ enablePersistAd: true });
#
# 				var adInfoList = [];
#
# 				adInfoList.push({
# 					seq: 1,
# 					unitId: "p_news_newslist",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "",
# 					calp: false,
# 					hasSid1: true
# 				});
# 				adInfoList.push({
# 					seq: 2,
# 					unitId: "p_news_sidebox",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "",
# 					calp: true,
# 					hasSid1: false
# 				});
#
# 				var userAgent = navigator.userAgent.toLowerCase();
#
# 				for (var i = 0; i < adInfoList.length; i++) {
# 					var adInfo = adInfoList[i];
#
# 					var divId = "nmap_c_" + article.officeId + "_" + article.articleId + "_" + article.sectionId + "_" + adInfo.seq;
#
# 					var unitId = adInfo.unitId;
# 					var mobileOnly = adInfo.mobileOnly;
# 					var sync = adInfo.sync;
# 					var isArticle = adInfo.article;
# 					var directSalesPct = adInfo.directSalesPct;
# 					var calp = adInfo.calp;
# 					var hasSid1 = adInfo.hasSid1;
#
# 					if (mobileOnly == true) {
# 						if (/iphone|android|ipod/.test(userAgent) == false) {
# 							continue;
# 						}
# 					}
#
# 					var customParam = {
# 						sid1: article.sectionId,
# 						oid: article.officeId,
# 						gdid: article.gdid,
# 						pk: searchQuery,
# 						directSalesPct: directSalesPct
# 					};
#
# 					if (calp == true) {
# 						customParam.calp = "shome";
# 					}
# 					if (hasSid1 == true) {
# 						customParam.sid1 = "100";
# 					}
#
# 					var adUnit = {
# 						adUnitId: unitId,
# 						adSlotElementId: divId,
# 						customParam: customParam
# 					};
#
# 					if (sync == true) {
# 						syncUnitIds.push(unitId);
# 						syncDivIds.push(divId);
#
# 						if (isArticle == false) {
# 							syncUnitIdsForNonArticle.push(unitId);
# 							syncDivIdsForNonArticle.push(divId);
# 						}
# 					} else {
# 						unitIds.push(unitId);
# 						divIds.push(divId);
# 					}
#
# 					gladsdk.defineAdSlot(adUnit);
# 				}
#
# 			});
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 		</script>
# <script src="https://static-nnews.pstatic.net/js/min/20250717/common.min.js"></script>
# </link></meta></head>
# <body class="n_news_mnews fs1 as_mp_layout as_section_home">
# <div class="end_container">
# <div class="u_skip"><a href="#ct">본문 바로가기</a></div>
# <header class="as_gnb_mnews as_type_section" role="banner">
# <div class="header_inner">
# <div class="Ngnb">
# <div class="Ngnb_inner">
# <div class="Ngnb_both">
# <div class="Ngnb_left">
# <span class="Ngnb_logo"><a class="Nlogo_link _LINK" data-clk="gnb.naver" data-pc-url="https://www.naver.com/" data-url="https://m.naver.com/" href="https://m.naver.com/"><span class="Nicon_logo">NAVER</span></a></span>
# <div class="Ngnb_service">
# <h1 class="Nservice_item"><a class="_LINK" data-clk="gnb.news" data-pc-url="https://news.naver.com/" data-url="https://m.news.naver.com" href="https://m.news.naver.com"><span class="Nicon_service">뉴스</span></a></h1>
# <span class="Nservice_subitem">
# <a class="_LINK" data-clk="gnb.entertain" data-pc-url="https://entertain.naver.com/home" data-url="https://m.entertain.naver.com" href="https://m.entertain.naver.com">
# <span class="Nicon_family Nicon_entertain">엔터</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a class="_LINK" data-clk="gnb.sports" data-pc-url="https://sports.news.naver.com/index" data-url="https://m.sports.naver.com" href="https://m.sports.naver.com">
# <span class="Nicon_family Nicon_sports">스포츠</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.weather" href="https://weather.naver.com">
# <span class="Nicon_family Nicon_weather">날씨</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.premium" href="https://contents.premium.naver.com">
# <span class="Nicon_family Nicon_premium">프리미엄</span>
# </a>
# </span>
# </div>
# </div>
# <div class="Ngnb_right">
# <div class="Ngnb_group">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="Ngnb_search _SEARCH_WRAP is_hidden"></div>
# <div class="Ngnb_tool">
# <a class="Ntool_button _SEARCH_CONTENT_TOGGLE_BUTTON" data-clk="gnb.scho" href="javascript:;"><span class="Nicon_search">검색</span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="Nlnb" data-scroll-fixed="true" id="_LNB_PARENT_WRAP" style="z-index:3000;">
# <div class="Nlnb_menu Ntype_scroll" id="_LNB_WRAP">
# <div class="Nlnb_menu_inner" id="_LNB">
# <ul class="Nlnb_menu_list" role="tablist">
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.press" href="https://news.naver.com/" role="tab"><span class="Nitem_link_menu">언론사별</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM is_active" role="presentation">
# <a aria-selected="true" class="Nitem_link" data-clk="lnb.pol" href="https://news.naver.com/section/100" role="tab"><span class="Nitem_link_menu">정치</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.eco" href="https://news.naver.com/section/101" role="tab"><span class="Nitem_link_menu">경제</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.soc" href="https://news.naver.com/section/102" role="tab"><span class="Nitem_link_menu">사회</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.lif" href="https://news.naver.com/section/103" role="tab"><span class="Nitem_link_menu">생활/문화</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.it" href="https://news.naver.com/section/105" role="tab"><span class="Nitem_link_menu">IT/과학</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.wor" href="https://news.naver.com/section/104" role="tab"><span class="Nitem_link_menu">세계</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.rank" href="https://news.naver.com/main/ranking/popularDay.naver?mid=etc&amp;sid1=111" role="tab"><span class="Nitem_link_menu">랭킹</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.paper" href="https://news.naver.com/newspaper/home" role="tab"><span class="Nitem_link_menu">신문보기</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.opi" href="https://news.naver.com/main/opinion/home.naver" role="tab"><span class="Nitem_link_menu">오피니언</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.tv" href="https://news.naver.com/main/tv/index.naver?mid=tvh" role="tab"><span class="Nitem_link_menu">TV</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.fact" href="https://news.naver.com/main/factcheck/main.naver" role="tab"><span class="Nitem_link_menu">팩트체크</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.algo" href="https://media.naver.com/algorithm" role="tab"><span class="Nitem_link_menu">알고리즘 안내</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.correct" href="https://news.naver.com/ombudsman/errorArticleList" role="tab"><span class="Nitem_link_menu">정정보도 모음</span></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </header>
# <hr/>
# <script>
# 	var svt = "20250723155446.720";
# 	var timestamp = svt.substr(0, 8);
# 	var isLogin = false;
# 	var uhv = "";
#
# 	var service = {
# 		news: false,
# 		entertain: false,
# 		sports: false,
# 		mnews: true,
# 		newsType: true
# 	};
# 	var serviceName = "mnews";
#
# 	var nilNtmUrl = "https://ntm.pstatic.net/scripts/ntm_b7032129a433.js";
#
# 	var envPhase = "production";
# 	var isProduction = true;
#
# 	var gnb_service = "news";
# 	var gnb_logout = encodeURIComponent(location.href);
# 	var gnb_template = "gnb_utf8";
# 	var gnb_brightness = 3;
# 	var gnb_item_hide_option = 128;
#
# 	var isDegradeMode = false;
# 	var isDegradeN2Mode = false;
# </script>
# <div class="ct_wrap" id="ct_wrap">
# <div class="ct_lnb">
# <div class="ct_lnb_inner">
# <strong class="ct_lnb_date">07.23(수)</strong>
# <ul class="ct_lnb_side">
# <li class="ct_lnb_side_item">
# <a class="ct_lnb_side_link" data-clk="slb.allmedia" href="https://news.naver.com/main/officeList.naver">전체 언론사</a>
# </li>
# <li class="ct_lnb_side_item">
# <a class="ct_lnb_side_link" data-clk="slb.newsstand" href="https://newsstand.naver.com/" target="_blank">뉴스스탠드</a>
# </li>
# <li class="ct_lnb_side_item">
# <a class="ct_lnb_side_link" data-clk="slb.library" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank">라이브러리</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="ct_scroll_wrapper">
# <div class="column0">
# <div class="ct_snb">
# <h2 class="ct_snb_h2">
# <a class="ct_snb_h2_a" data-clk="lmn_pol.home" href="/section/100">정치</a>
# </h2>
# <ul class="ct_snb_nav">
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_pol.mnl" data-rank="1" href="/breakingnews/section/100/264">대통령실</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_pol.mnl" data-rank="2" href="/breakingnews/section/100/265">국회/정당</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_pol.mnl" data-rank="3" href="/breakingnews/section/100/268">북한</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_pol.mnl" data-rank="4" href="/breakingnews/section/100/266">행정</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_pol.mnl" data-rank="5" href="/breakingnews/section/100/267">국방/외교</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_pol.mnl" data-rank="6" href="/breakingnews/section/100/269">정치일반</a>
# </li>
# </ul>
# <div class="ct_snb_banner _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <a data-clk="lmn_pol.pmb" data-rank="1" href="https://media.naver.com/algorithm">
# <img alt="AI 뉴스 알고리즘" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://imgnews.pstatic.net/image/upload/item/2023/07/10/184436024_banner_left.png" height="74" style="display: none;" width="71"/>
# </a>
# </div>
# <div class="ct_snb_banner _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <a data-clk="lmn_pol.pmb" data-rank="2" href="https://contents.premium.naver.com/">
# <img alt="프리미엄콘텐츠" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" height="74" style="display: none;" width="71"/>
# </a>
# </div>
# </div>
# </div>
# <div class="newsct_wrapper _GRID_TEMPLATE_COLUMN _STICKY_CONTENT" id="newsct" role="main"><div class="section_component as_section_headline _PERSIST_CONTENT" data-persist="2_sectionHeadline">
# <div class="section_article as_headline _TEMPLATE" data-template-id="SECTION_HEADLINE">
# <div class="sa_head">
# <span class="sa_head_inner">
# <a class="sa_head_link _TOGGLE" data-classvalue="is_hidden" data-clk="guide" data-target="_SECTION_HEADLINE_INFO_879k0" href="#">헤드라인 뉴스 <i class="sa_head_icon">안내</i></a>
# </span>
# <div class="sa_head_layer is_hidden" id="_SECTION_HEADLINE_INFO_879k0">
# <p class="sa_head_layer_p">각 헤드라인의 기사와 배열 순서는 개인화를 반영해 추천되며, 기사묶음의 대표 기사는 구독 언론사 중심으로 제공됩니다. 기사 수량이 표기된 기사 우측 하단의 파란색 아이콘을 클릭하면 기사묶음을 확인할 수 있고 기사묶음과 기사묶음 타이틀도 기사 내용을 기반으로 자동 추출됩니다.</p>
# <a class="sa_head_layer_go" href="https://media.naver.com/algorithm">알고리즘 자세히 보기</a>
# <div class="sa_head_layer_close">
# <button class="_TOGGLE" data-classvalue="is_hidden" data-target="_SECTION_HEADLINE_INFO_879k0" type="button">닫기</button>
# </div>
# </div>
# </div>
# <ul class="sa_list" id="_SECTION_HEADLINE_LIST_879k0">
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="pol.clart" data-imp-gdid="88000385_000000000000000005626928" data-imp-index="1" data-imp-url="https://n.news.naver.com/mnews/article/277/0005626928" href="https://n.news.naver.com/mnews/article/277/0005626928">
# <img alt="국회, 김상환 헌재소장 임명동의안 가결…찬성 206표·반대 49표" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/277/2025/07/23/5626928.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="pol.clart" data-imp-gdid="88000385_000000000000000005626928" data-imp-index="1" data-imp-url="https://n.news.naver.com/mnews/article/277/0005626928" href="https://n.news.naver.com/mnews/article/277/0005626928">
# <strong class="sa_text_strong">국회, 김상환 헌재소장 임명동의안 가결…찬성 206표·반대 49표</strong>
# </a>
# <div class="sa_text_lede">김상환 헌법재판소장 후보자(59·사법연수원 20기) 임명동의안이 23일 여야 합의로 국회 본회의를 통과했다. 국회는 이날 본회의를 열고 이재명 대통령 몫인 김 후보자 임명동의안을 재석 264명 가운데 찬성 206명,</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">아시아경제</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news277,0005626928" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/277/0005626928" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202507231500_00000003/section/100?oid=277&amp;aid=0005626928">
# <span class="sa_text_cluster_num">20</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="pol.clart" data-imp-gdid="88000114_000000000000000011994600" data-imp-index="2" data-imp-url="https://n.news.naver.com/mnews/article/056/0011994600" href="https://n.news.naver.com/mnews/article/056/0011994600">
# <img alt="아들과 함께 임명장 받은 정은경·김영훈 장관 [이런뉴스]" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/056/2025/07/23/11994600.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# <span class="sa_thumb_play">
# <em class="blind">동영상뉴스</em>
# </span>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="pol.clart" data-imp-gdid="88000114_000000000000000011994600" data-imp-index="2" data-imp-url="https://n.news.naver.com/mnews/article/056/0011994600" href="https://n.news.naver.com/mnews/article/056/0011994600">
# <strong class="sa_text_strong">아들과 함께 임명장 받은 정은경·김영훈 장관 [이런뉴스]</strong>
# </a>
# <div class="sa_text_lede">이재명 대통령은 구윤철 경제부총리 겸 기획재정부 장관 등 신임 장관에 임명장을 수여했습니다 . 이 대통령은 오늘 (23 일 ) 오전 용산 대통령실에서 신임 장관 8 명에게 " 축하한다 ", " 잘 부탁드린다 " 는</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">KBS</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news056,0011994600" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/056/0011994600" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202507231130_00000003/section/100?oid=056&amp;aid=0011994600">
# <span class="sa_text_cluster_num">25</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="pol.clart" data-imp-gdid="880000AF_000000000000000002222944" data-imp-index="3" data-imp-url="https://n.news.naver.com/mnews/article/052/0002222944" href="https://n.news.naver.com/mnews/article/052/0002222944">
# <img alt='강선우 여진 계속...인사처장 "TV 없어 갑질 논란 몰라"' class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/052/2025/07/22/2222944.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# <span class="sa_thumb_play">
# <em class="blind">동영상뉴스</em>
# </span>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="pol.clart" data-imp-gdid="880000AF_000000000000000002222944" data-imp-index="3" data-imp-url="https://n.news.naver.com/mnews/article/052/0002222944" href="https://n.news.naver.com/mnews/article/052/0002222944">
# <strong class="sa_text_strong">강선우 여진 계속...인사처장 "TV 없어 갑질 논란 몰라"</strong>
# </a>
# <div class="sa_text_lede">이처럼 강선우 여성가족부 장관 후보자가 사실상 임명 수순에 들어가면서, 정치권 공방은 더욱 거세지고 있습니다. 이런 가운데 최동석 신임 인사혁신처장이 오늘 국회에 출석해 강 후보자를 둘러싼 논란을 모른다고 답해 파장</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">YTN</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news052,0002222944" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/052/0002222944" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202507220920_00000006/section/100?oid=052&amp;aid=0002222944">
# <span class="sa_text_cluster_num">64</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="pol.clart" data-imp-gdid="880000A9_000000000000000003649845" data-imp-index="4" data-imp-url="https://n.news.naver.com/mnews/article/020/0003649845" href="https://n.news.naver.com/mnews/article/020/0003649845">
# <img alt="金총리 “경주 APEC, 지난 정부서 준비 미진…성공 미지수”" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/020/2025/07/23/3649845.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="pol.clart" data-imp-gdid="880000A9_000000000000000003649845" data-imp-index="4" data-imp-url="https://n.news.naver.com/mnews/article/020/0003649845" href="https://n.news.naver.com/mnews/article/020/0003649845">
# <strong class="sa_text_strong">金총리 “경주 APEC, 지난 정부서 준비 미진…성공 미지수”</strong>
# </a>
# <div class="sa_text_lede">경북 경주에서 열리는 2025년 아시아태평양 경제협력체(APEC) 정상회의가 약 100일 앞으로 다가온 가운데, APEC 준비위원장인 김민석 국무총리는 “새 정부가 이어받은 APEC 준비 대차대조표는 부실하고 시간은</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">동아일보</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news020,0003649845" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/020/0003649845" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202507161730_00000006/section/100?oid=020&amp;aid=0003649845">
# <span class="sa_text_cluster_num">41</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="pol.clart" data-imp-gdid="88156f73_000000000000000000544432" data-imp-index="5" data-imp-url="https://n.news.naver.com/mnews/article/448/0000544432" href="https://n.news.naver.com/mnews/article/448/0000544432">
# <img alt='김상욱 "강선우, 국민수용성 과락…결자해지의 심정으로 직접 나서야"' class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/448/2025/07/23/544432.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="pol.clart" data-imp-gdid="88156f73_000000000000000000544432" data-imp-index="5" data-imp-url="https://n.news.naver.com/mnews/article/448/0000544432" href="https://n.news.naver.com/mnews/article/448/0000544432">
# <strong class="sa_text_strong">김상욱 "강선우, 국민수용성 과락…결자해지의 심정으로 직접 나서야"</strong>
# </a>
# <div class="sa_text_lede">김상욱 더불어민주당 의원이 23일 강선우 여성가족부 장관 후보자의 갑질 논란과 관련해 "결자해지의 심정으로 후보자께서 직접 나서주셨으면 하는 생각도 있다"고 말했다. 김 의원은 이날 YTN라디오 '뉴스파이팅'에서 "</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">TV조선</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news448,0000544432" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/448/0000544432" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202507230940_00000003/section/100?oid=448&amp;aid=0000544432">
# <span class="sa_text_cluster_num">24</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE is_blind">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="pol.clart" data-imp-gdid="08138260_000000000000000000449736" data-imp-index="6" data-imp-url="https://n.news.naver.com/mnews/article/437/0000449736" href="https://n.news.naver.com/mnews/article/437/0000449736">
# <img alt="&quot;'개딸·나라 망하는 길'…극우 유튜버 흉내&quot; 박주민, 오세훈 비판" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/437/2025/07/23/449736.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="pol.clart" data-imp-gdid="08138260_000000000000000000449736" data-imp-index="6" data-imp-url="https://n.news.naver.com/mnews/article/437/0000449736" href="https://n.news.naver.com/mnews/article/437/0000449736">
# <strong class="sa_text_strong">"'개딸·나라 망하는 길'…극우 유튜버 흉내" 박주민, 오세훈 비판</strong>
# </a>
# <div class="sa_text_lede">박주민 더불어민주당 의원이 오세훈 서울시장을 겨냥해 "극우 유튜버가 되기로 한 것이냐"고 비판했습니다. 박 의원은 어제(22일) 자신의 페이스북에 글을 올려 "두 눈을 의심했다. 해킹이라도 당한 줄 알았다"며 "서울</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">JTBC</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news437,0000449736" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/437/0000449736" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202507230900_00000071/section/100?oid=437&amp;aid=0000449736">
# <span class="sa_text_cluster_num">14</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE is_blind">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="pol.clart" data-imp-gdid="8800010E_000000000000000002503693" data-imp-index="7" data-imp-url="https://n.news.naver.com/mnews/article/016/0002503693" href="https://n.news.naver.com/mnews/article/016/0002503693">
# <img alt="여야, 국힘 몫 인권위원 선출안 본회의 상정 보류" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/016/2025/07/23/2503693.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="pol.clart" data-imp-gdid="8800010E_000000000000000002503693" data-imp-index="7" data-imp-url="https://n.news.naver.com/mnews/article/016/0002503693" href="https://n.news.naver.com/mnews/article/016/0002503693">
# <strong class="sa_text_strong">여야, 국힘 몫 인권위원 선출안 본회의 상정 보류</strong>
# </a>
# <div class="sa_text_lede">우원식 국회의장과 김병기 더불어민주당 대표 직무대행 겸 원내대표, 송언석 국민의힘 비상대책위원장 겸 원내대표가 23일 오전 국회 국회의장실에서 회동을 갖고 기념 촬영을 하고 있다. 왼쪽부터 문진석 민주당 원내수석부대</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">헤럴드경제</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news016,0002503693" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/016/0002503693" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202507221910_00000302/section/100?oid=016&amp;aid=0002503693">
# <span class="sa_text_cluster_num">35</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE is_blind">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="pol.clart" data-imp-gdid="88000119_000000000000000001438218" data-imp-index="8" data-imp-url="https://n.news.naver.com/mnews/article/214/0001438218" href="https://n.news.naver.com/mnews/article/214/0001438218">
# <img alt='국힘 조경태, 혁신파 후보 단일화 제안‥"내란당 치욕 벗어나야"' class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/214/2025/07/23/1438218.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="pol.clart" data-imp-gdid="88000119_000000000000000001438218" data-imp-index="8" data-imp-url="https://n.news.naver.com/mnews/article/214/0001438218" href="https://n.news.naver.com/mnews/article/214/0001438218">
# <strong class="sa_text_strong">국힘 조경태, 혁신파 후보 단일화 제안‥"내란당 치욕 벗어나야"</strong>
# </a>
# <div class="sa_text_lede">국민의힘 대표 출마를 선언한 조경태 의원이 당권에 도전하는, 이른바 혁신파 후보 단일화를 제안했습니다. 조 의원은 오늘 국회에서 기자회견을 열어 "혁신 후보 단일화로 승리해 국민의힘을 내란당이라는 치욕스러운 오명에서</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">MBC</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news214,0001438218" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/214/0001438218" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202507230950_00000009/section/100?oid=214&amp;aid=0001438218">
# <span class="sa_text_cluster_num">19</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE is_blind">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="pol.clart" data-imp-gdid="88221sge_000000000000000000141246" data-imp-index="9" data-imp-url="https://n.news.naver.com/mnews/article/656/0000141246" href="https://n.news.naver.com/mnews/article/656/0000141246">
# <img alt='野 "강선우 청문회 하루 더 하자" 민주당에 공식 제안' class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/656/2025/07/23/141246.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="pol.clart" data-imp-gdid="88221sge_000000000000000000141246" data-imp-index="9" data-imp-url="https://n.news.naver.com/mnews/article/656/0000141246" href="https://n.news.naver.com/mnews/article/656/0000141246">
# <strong class="sa_text_strong">野 "강선우 청문회 하루 더 하자" 민주당에 공식 제안</strong>
# </a>
# <div class="sa_text_lede">송언석 국민의힘 비상대책위원장 겸 원내대표가 23일 갑질 의혹을 받는 강선우 여성가족부 장관 후보자에 대한 인사청문회를 추가 실시하자고 더불어민주당에 제안했다. 송 비대위원장은 이날 국회에서 열린 의원총회에서 "보좌</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">대전일보</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news656,0000141246" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/656/0000141246" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202507231110_00000088/section/100?oid=656&amp;aid=0000141246">
# <span class="sa_text_cluster_num">22</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE is_blind">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="pol.clart" data-imp-gdid="880000D8_000000000000000015523201" data-imp-index="10" data-imp-url="https://n.news.naver.com/mnews/article/001/0015523201" href="https://n.news.naver.com/mnews/article/001/0015523201">
# <img alt='대통령실, 이진숙 여름휴가 신청 반려…"재난 상황서 부적절"' class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/001/2025/07/22/15523201.jpg?type=nf220_150" height="75" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="pol.clart" data-imp-gdid="880000D8_000000000000000015523201" data-imp-index="10" data-imp-url="https://n.news.naver.com/mnews/article/001/0015523201" href="https://n.news.naver.com/mnews/article/001/0015523201">
# <strong class="sa_text_strong">대통령실, 이진숙 여름휴가 신청 반려…"재난 상황서 부적절"</strong>
# </a>
# <div class="sa_text_lede">李, 위기경보 '심각' 단계였던 18일 '25∼31일 여름휴가' 신청 대통령실이 이진숙 방송통신위원장의 여름휴가 신청을 '재난 상황 속에 재난 방송을 책임지는 기관장의 휴가는 부적절하다'는 이</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">연합뉴스</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news001,0015523201" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/001/0015523201" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202507221750_00000001/section/100?oid=001&amp;aid=0015523201">
# <span class="sa_text_cluster_num">51</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="section_more _SECTION_HEADLINE_MORE_BUTTON_WRAP">
# <a class="section_more_inner _SECTION_HEADLINE_MORE_BUTTON _NLOG_IMPRESSION_TRIGGER" data-clk="clsmore" data-target="_SECTION_HEADLINE_LIST_879k0" href="#">헤드라인 더보기</a>
# </div>
# </div>
# <div class="section_component as_section_series _PERSIST_CONTENT" data-persist="3_sectionSeries">
# <div class="section_series _TEMPLATE" data-template-id="SECTION_SERIES">
# <div class="ss_head">
# <div class="ss_head_inner">
# <a class="ss_head_link" data-clk="sert" href="https://news.naver.com/hotissue/main?sid1=163&amp;cid=2001087">
# <span class="ss_head_go">연재보기</span>
# <h2 class="ss_head_topic">이현호의 밀리터리!톡</h2>
# </a>
# </div>
# </div>
# <div class="ss_body">
# <ul class="ss_list">
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="pol.sera" data-imp-gdid="88000108_000000000000000004512365" data-imp-index="kdocu" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/011/0004512365?type=series&amp;cid=2001087" href="https://n.news.naver.com/mnews/hotissue/article/011/0004512365?type=series&amp;cid=2001087">
# <img alt="北 2040년 핵무기 보유량은…430발·핵탄두 연간 17발 생산" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/011/2025/07/23/4512365.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="pol.sera" data-imp-gdid="88000108_000000000000000004512365" data-imp-index="kdocu" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/011/0004512365?type=series&amp;cid=2001087" href="https://n.news.naver.com/mnews/hotissue/article/011/0004512365?type=series&amp;cid=2001087">北 2040년 핵무기 보유량은…430발·핵탄두 연간 17발 생산</a>
# <div class="ss_text_lede">2023년 1월 북한 김정은 국무위원장은 조선노동당 전원회의를 통해 “핵탄 보유량을 기하급수적으로 늘릴 것”을 지시하며 북한의 핵전력 건설 정책에 새로운 국면을 예고했다. 이 같은 발언은 단발적인 수사가 아닌 이후 </div>
# <div class="ss_text_info">
# <div class="ss_text_press">서울경제</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news011,0004512365" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/011/0004512365" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="pol.sera" data-imp-gdid="88000108_000000000000000004511884" data-imp-index="0p1vf" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/011/0004511884?type=series&amp;cid=2001087" href="https://n.news.naver.com/mnews/hotissue/article/011/0004511884?type=series&amp;cid=2001087">
# <img alt="통합사관학교 “글쎄”…본질은 사관vs비사관 ‘동등한 진급’ 인사" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/011/2025/07/22/4511884.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="pol.sera" data-imp-gdid="88000108_000000000000000004511884" data-imp-index="0p1vf" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/011/0004511884?type=series&amp;cid=2001087" href="https://n.news.naver.com/mnews/hotissue/article/011/0004511884?type=series&amp;cid=2001087">통합사관학교 “글쎄”…본질은 사관vs비사관 ‘동등한 진급’ 인사</a>
# <div class="ss_text_lede">이재명 대통령은 대선 기간 ‘군 교육기관 단계적 통합’을 공약했다. 이 공약은 육·해·공군 사관학교 통합을 의미하는 것이라는 해석이 나왔다. 이런 가운데 안규백 국방부 장관 후보자는 국민의힘 강대식 의원의 질의에 대</div>
# <div class="ss_text_info">
# <div class="ss_text_press">서울경제</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news011,0004511884" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/011/0004511884" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="pol.sera" data-imp-gdid="88000108_000000000000000004511391" data-imp-index="tfdwe" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/011/0004511391?type=series&amp;cid=2001087" href="https://n.news.naver.com/mnews/hotissue/article/011/0004511391?type=series&amp;cid=2001087">
# <img alt="[단독] 방위사업청, 20년 만에 ‘방위산업청’으로 문패 바꾸나" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/011/2025/07/21/4511391.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="pol.sera" data-imp-gdid="88000108_000000000000000004511391" data-imp-index="tfdwe" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/011/0004511391?type=series&amp;cid=2001087" href="https://n.news.naver.com/mnews/hotissue/article/011/0004511391?type=series&amp;cid=2001087">[단독] 방위사업청, 20년 만에 ‘방위산업청’으로 문패 바꾸나</a>
# <div class="ss_text_lede">이재명 대통령은 지난 7월 8일 서울 용산구 그랜드하얏트 호텔에서 열린 제1회 방위산업의 날 기념식에서 “방위산업이 대한민국의 안보를 튼튼하게 할 뿐 아니라 나아가 대한민국의 미래 먹거리 산업의 하나로 자리 잡기를 </div>
# <div class="ss_text_info">
# <div class="ss_text_press">서울경제</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news011,0004511391" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/011/0004511391" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link _NLOG_IMPRESSION" data-clk="pol.sera" data-imp-gdid="88000108_000000000000000004511136" data-imp-index="ntzfu" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/011/0004511136?type=series&amp;cid=2001087" href="https://n.news.naver.com/mnews/hotissue/article/011/0004511136?type=series&amp;cid=2001087">
# <img alt="美 vs 中, 우주軍 전쟁 때 승부처는…‘위성 요격’ 기술력" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/011/2025/07/20/4511136.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline _NLOG_IMPRESSION" data-clk="pol.sera" data-imp-gdid="88000108_000000000000000004511136" data-imp-index="ntzfu" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/011/0004511136?type=series&amp;cid=2001087" href="https://n.news.naver.com/mnews/hotissue/article/011/0004511136?type=series&amp;cid=2001087">美 vs 中, 우주軍 전쟁 때 승부처는…‘위성 요격’ 기술력</a>
# <div class="ss_text_lede">지난 6월 26일(현지 시간) 미 의회 상원 예산위원회 국방 소위 공군 청문회에서 챈스 솔츠먼 우주군 참모총장은 “중국의 우주 무기가 미국은 물론 전 세계 동맹국에도 큰 위협”이라며 “중국은 총 1060개의 위성을 </div>
# <div class="ss_text_info">
# <div class="ss_text_press">서울경제</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news011,0004511136" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/011/0004511136" style="display: none;"></a>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="r_group_comp ad_box _da_banner _PERSIST_HEIGHT is_border_none" data-persist="1_ad">
# <div class="ad_area _AD_WRAP" data-article="false" data-mobileonly="false" data-sync="false" data-unitid="p_news_newslist" id="nmap_c____1"></div>
# </div>
# <div class="section_latest">
# <div class="section_component as_section_article_list _PERSIST_CONTENT" data-persist="SECTION_ARTICLE_LIST">
# <div class="section_latest_article _CONTENT_LIST _PERSIST_META" data-cluid="" data-cursor="20250723142219" data-cursor-name="next" data-date="" data-has-next="true" data-nclk="airscont" data-page-no="1" data-persist="SECTION_ARTICLE_LIST_META" data-persist-meta-restore="true" data-sid="100" data-sid2="" data-template="SECTION_ARTICLE_LIST">
# <div class="section_article _TEMPLATE" data-template-id="SECTION_ARTICLE_LIST">
# <ul class="sa_list">
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"8KWNQtHmhuhaWbi0"}}' data-gdid="880000C4_000000000000000002724748" data-imp-url="https://n.news.naver.com/mnews/article/021/0002724748" data-rank="1" href="https://n.news.naver.com/mnews/article/021/0002724748">
# <img alt="[속보]“아프지만 누군가 말해야” 박찬대도 강선우 사퇴 요청" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/021/2025/07/23/2724748.jpg?type=ofullfill220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"8KWNQtHmhuhaWbi0"}}' data-gdid="880000C4_000000000000000002724748" data-imp-url="https://n.news.naver.com/mnews/article/021/0002724748" data-rank="1" href="https://n.news.naver.com/mnews/article/021/0002724748">
# <strong class="sa_text_strong">[속보]“아프지만 누군가 말해야” 박찬대도 강선우 사퇴 요청</strong>
# </a>
# <div class="sa_text_lede">강선우 여성가족부 장관 후보자가 14일 서울 여의도 국회에서 열린 여성가족위원회의 인사청문회에서 의원 질의에 답하고 있다. 뉴시스 정청래 더불어민주당 의원과 당대표를 두고 경합 중인 박찬대 의원은 23일 갑질 의혹으</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">문화일보</div>
# <div class="sa_text_datetime is_recent">
# <b>9분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news021,0002724748" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/021/0002724748" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"8KWNQtHmhuhaWbi0"}}' data-gdid="880000E3_000000000000000002482070" data-imp-url="https://n.news.naver.com/mnews/article/047/0002482070" data-rank="2" href="https://n.news.naver.com/mnews/article/047/0002482070">
# <img alt='"금융위 해체 확실히 말해야.. 정부 망설임, 모피아 로비 의심"' class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/047/2025/07/23/2482070.jpg?type=ofullfill220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"8KWNQtHmhuhaWbi0"}}' data-gdid="880000E3_000000000000000002482070" data-imp-url="https://n.news.naver.com/mnews/article/047/0002482070" data-rank="2" href="https://n.news.naver.com/mnews/article/047/0002482070">
# <strong class="sa_text_strong">"금융위 해체 확실히 말해야.. 정부 망설임, 모피아 로비 의심"</strong>
# </a>
# <div class="sa_text_lede">▲ 김소영 금융위원회 부위원장이 지난 2월 19일 정부서울청사에서 정책금융 조기집행 간담회를 하고 있다. ⓒ 연합뉴스 "해리포터에서 볼드모트의 이름을 말할 수 있느냐 없느냐에 따라서 향방이 갈리듯, 이제는 말할 수 </div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">오마이뉴스</div>
# <div class="sa_text_datetime is_recent">
# <b>13분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news047,0002482070" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/047/0002482070" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"8KWNQtHmhuhaWbi0"}}' data-gdid="8800006B_000000000000000003384818" data-imp-url="https://n.news.naver.com/mnews/article/032/0003384818" data-rank="3" href="https://n.news.naver.com/mnews/article/032/0003384818">
# <img alt="권칠승, ‘의원과 보좌진은 동지’ 발언 논란에 “전혀 경우에 맞지 않아”" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/032/2025/07/23/3384818.jpg?type=ofullfill220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="airscont" data-extra='{"airs":{"model_version":"news_sec_v2.0","session_id":"8KWNQtHmhuhaWbi0"}}' data-gdid="8800006B_000000000000000003384818" data-imp-url="https://n.news.naver.com/mnews/article/032/0003384818" data-rank="3" href="https://n.news.naver.com/mnews/article/032/0003384818">
# <strong class="sa_text_strong">권칠승, ‘의원과 보좌진은 동지’ 발언 논란에 “전혀 경우에 맞지 않아”</strong>
# </a>
# <div class="sa_text_lede">권칠승 더불어민주당 의원이 23일 ‘의원과 보좌진은 동지적 관계’라고 말 한 문진석 원내운영수석부대표의 발언을 두고 “지금 와서는 그런 것을 일반적으로 이야기한다는 것은 전혀 경우에 맞지 않는다”고 말했다. 문 원내</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">경향신문</div>
# <div class="sa_text_datetime is_recent">
# <b>16분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# ...
# </span>
# <span class="u_cri u_cri_v1">
# <a class="u_cra _LINK" data-clk="fot.serviceall" data-pc-url="https://www.naver.com/more.html" data-url="https://m.naver.com/services.html?f=svc.news" href="https://m.naver.com/services.html?f=svc.news">전체서비스</a>
# </span>
# </span>
# <span class="u_ftm">
# <span class="u_cri u_cri_v1">
# <a class="u_cra" data-clk="fot.guide" href="https://news.naver.com/ombudsman">서비스안내</a>
# </span>
# <span class="u_cri u_cri_v1">
# <a class="u_cra" data-clk="fot.report" href="https://help.naver.com/alias/news/news_001.naver">오류신고</a>
# </span>
# <span class="u_cri u_cri_v1">
# <a class="u_cra" data-clk="fot.help" href="https://help.naver.com/alias/news/news_007.naver">고객센터</a>
# </span>
# </span>
# <span class="u_charge">
# <a class="u_charge_item" data-clk="fot.editor" href="https://news.naver.com/ombudsman/edit">기사배열 책임자 : 김수향</a>
# <span class="u_charge_item">청소년 보호 책임자 : 이정규</span>
# </span>
# <span class="u_copyright">
# 					이 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며, 이를 무단 <br/>이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.
# 				</span>
# <span class="u_naverlogo">
# <a class="u_naverlogo_a" data-clk="fot.navercorp" href="https://www.navercorp.com">NAVER</a>
# </span>
# </p>
# </footer>
# </div>
# </div>
# <a class="r_pg_top show _MOVE_TOP" data-clk="fot.top" href="#" id="goTop" style="display:none;">맨위로</a>
# <div class="subscribe_dimmed is_hidden" id="_MY_FEED_CANCEL_MODAL" style="display:none;">
# <div class="subscribe_alert">
# <p class="subscribe_alert_p _message _MY_FFED_CANCEL_MODAL_MESSAGE">
# </p>
# <div class="subscribe_alert_btns">
# <a class="subscribe_alert_btn _CANCEL_YES_BTN _TOGGLE" data-classvalue="is_hidden" data-target="_MY_FEED_CANCEL_MODAL" href="#">예</a>
# <a class="subscribe_alert_btn _TOGGLE" data-classvalue="is_hidden" data-target="_MY_FEED_CANCEL_MODAL" href="#">아니오</a>
# </div>
# </div>
# </div>
# <script class="_MY_FEED_CANCEL_MODAL_TEMPLATE" type="x-tmpl-mustache">
# 			{{#series}}
# 			<span class="subscribe_alert_p_ellipsis">{{value}}</span><br>연재 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc">해당 연재는 <em>구독</em>에서 제외됩니다.</span>
# 			{{/series}}
# 			{{#journalist}}
# 			{{value}} 기자의 기사<br> 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc"><em>구독</em>에서 해당 기자의 기사가 제외됩니다.</span>
# 			{{/journalist}}
# </script>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION"></div>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION_ALL"></div>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION_OS"></div>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification is_single">
# 	<strong class="mn_ok">구독완료</strong>
# 	{{#officeInfos}}
# 	<div class="mn_text">
# 		<h4 class="mn_h">{{officeName}} 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<p class="mn_p">언론사의 주요 콘텐츠를 <br> 네이버에서 빠르게 확인할 수 있습니다.</p>
# 	</div>
# 	{{/officeInfos}}
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE" data-clk="{{nclk}}yes">알림받기</button>
# 	</div>
# </div>
# </script>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_ALL" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification">
# 	<strong class="mn_ok">구독완료</strong>
# 	<div class="mn_text">
# 		<h4 class="mn_h">언론사의 주요 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<ul class="mn_list">
# 			{{#officeInfos}}
# 			<li class="mn_item">
# 				<div class="mn_head">
# 					<div class="mn_img">
# 						<img src="{{logo}}" alt="" onerror="this.outerHTML='<span class=&quot;no_image&quot;></span>'">
# 					</div>
# 					<div class="mn_name">{{officeName}}</div>
# 				</div>
# 				<div class="mn_body">
# 					<button type="button" class="mn_noti _ALL_OFFICES_NOTIFICATION_ITEM" data-oid="{{officeId}}" data-clk-add="notchnon" data-clk-remove="notchnoff">알림받기 사용함</button>
# 				</div>
# 			</li>
# 			{{/officeInfos}}
# 		</ul>
# 	</div>
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE _CHANNEL_BANNER_ITEM_NOTICE_COMPLETE" data-clk="{{nclk}}yes">완료</button>
# 	</div>
# </div>
# </script>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_OS" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="napp_notify_notice">
# 	<div class="napp_notify_info_area">
# 		<strong class="napp_notify_title">네이버 앱 푸시알림이 꺼져있어요.</strong>
# 		<div class="napp_notify_desc_box">
# 			<p class="napp_notify_desc1">네이버 앱 알림켜기 &gt; 알림탭 &gt; 알림허용</p>
# 			<p class="napp_notify_desc2">버튼을 눌러 앱 알림 설정을 켜주세요.</p>
# 		</div>
# 	</div>
# 	<div class="napp_notify_button_area">
# 		<button type="button" class="napp_notify_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}.osnotoff">닫기</button>
# 		<button type="button" class="napp_notify_btn highlight _MODAL_LAYER_POSITIVE _NAPP_NOTIFY_COMPLETE" data-clk="{{nclk}}.osnoton">네이버 앱 알림 켜기</button>
# 	</div>
# </div>
# </div>
# </script>
# <div id="_MODAL_DIALOG_WRAP" style="display: none;"></div>
# <script class="_MODAL_DIALOG_TEMPLATE" type="x-tmpl-mustache">
# <div class="nds_dialog_dimmed">
# 	<div class="nds_dialog_basic">
# 		<div class="nds_dialog_content">
# 			{{#isTextType}}
# 			<p class="nds_dialog_text">{{content.title}}</p>
# 			{{/isTextType}}
# 			{{#isTitleType}}
# 			<strong class="nds_dialog_title">
# 				<span class="nds_dialog_title_ellipsis">{{content.headTitle}}</span>
# 				{{content.title}}
# 			</strong>
# 			<p class="nds_dialog_description">{{content.description}}</p>
# 			{{/isTitleType}}
# 		</div>
# 		<div class="nds_dialog_button_area">
# 			<div class="nds_button_main_action as_layout_5_5">
# 				{{#isCancel}}
# 				<button type="button" class="nds_button_wide _MODAL_CANCEL"{{#content.clk.cancelClk}} data-clk="{{content.clk.cancelClk}}"{{/content.clk.cancelClk}}>
# 				{{content.cancelMessage}}
# 				</button>
# 				{{/isCancel}}
# 				<button type="button" class="nds_button_wide as_primary _MODAL_CONFIRM"{{#content.clk.confirmClk}} data-clk="{{content.clk.confirmClk}}"{{/content.clk.confirmClk}}>
# 				{{content.confirmMessage}}
# 				</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# </script>
# <div id="_MODAL_TOAST" style="display: none;"></div>
# <script class="_MODAL_TOAST_TEMPLATE" type="x-tmpl-mustache">
# <div class="nds_popover_toast as_center">
# 	<div class="nds_toast_text_area">
# 		<div class="nds_toast_text_area"><span class="nds_toast_ellipsis_text"><strong>{{toastTitle}}</strong></span> {{toastMessage}}</div>
# 	</div>
# </div>
# </script>
# <div class="ticker" id="_TICKER_LAYER_FOR_NOTIFICATION" style="display: none;"></div>
# <script class="_TICKER_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# {{#officeInfos}}
# <p class="t_inner"><em class="t_point">{{officeName}}</em> 언론사 알림이 설정되었습니다.</p>
# {{/officeInfos}}
# </script>
# <script crossorigin="anonymous" onerror="neloSender.sendErrorToNelo('스크립트 로딩 에러 : ' + this.src);" src="https://static-nnews.pstatic.net/js/min/20250717/library.min.js"></script>
# <script crossorigin="anonymous" onerror="neloSender.sendErrorToNelo('스크립트 로딩 에러 : ' + this.src);" src="https://static-nnews.pstatic.net/js/min/20250717/read.min.js"></script>
# <script>
# 	window.ntm = window.ntm || [];
# 	var ntmOption = {};
#
# 	if (ntmOption) {
#
# 		var section = {};
# 		var redirectSection = {"id":"100","name":"정치"};
#
# 		ntmOption["channelId"] = article.officeId;
#
# 		// 기타 또는 주요 섹션 이름
# 		var nilSendSectionName = "기타";
# 		var nilSendSectionId = "";
# 		if (/100|101|102|103|104|105|106|107/.test(section.id)) {
# 			nilSendSectionName = section.name;
# 			nilSendSectionId = section.id;
# 		}
#
# 		// 기사 타입
# 		var htArticleTypeName = { "0": "text", "1": "photo", "2": "tv" };
# 		var articleTypeName = htArticleTypeName[article.type] || "";
#
# 		ntmOption["hitType"] = "cv";
# 		ntmOption["eventCategory"] = "post_view";
# 		ntmOption["uri"] = "";
# 		ntmOption["gdid"] = article.gdid;
# 		ntmOption["dimension1"] = encodeURIComponent(nilSendSectionName);
# 		ntmOption["dimension4"] = articleTypeName;
# 		ntmOption["optional2"] = nilSendSectionId;
#
# 		var journalistIdList = [];
#
# 		// 기자 목록
# 		$("._JOURNALIST_CARD ._JOURNALIST_ID").each(function (index, object) {
# 			var $this = $(object);
# 			var journalistId = $this.attr("data-journalistId");
#
# 			if (journalistId && journalistIdList.indexOf(journalistId) === -1) {
# 				journalistIdList.push(journalistId);
# 			}
# 		});
#
# 		if (journalistIdList.length > 0) {
# 			ntmOption["dimension3"] = journalistIdList.join("___");
# 		}
#
# 		if (location.href.match(/ntype=RANKING/)) {
# 			ntmOption["dimension5"] = "y";
# 		}
#
# 		if (service.sports || service.newsType) {
# 			ntmOption["dimension2"] = article.sectionInfo.secondSection + "." + article.sectionInfo.thirdSection;
# 		}
#
# 		var seriesComponentId = $("._VALID_SERIES").attr("data-component-id");
# 		ntmOption["dimension6"] = seriesComponentId;
#
# 		var issueComponentId = $("._ISSUE_ARTICLE_INFO").attr("data-component-id");
# 		ntmOption["dimension8"] = issueComponentId;
#
# 		if (/[?|&]type=breakingnews(&|$)/.test(location.href) === true) {
# 			if (/(m\.naver\.com)|(media\.naver\.com)|(news\.naver\.com\/?$)|(www\.naver\.com)/.test(document.referrer) === true) {
# 				ntmOption["dimension7"] = "breaking";
# 			}
# 		}
#
# 		var ntmLeaveOption = $.extend({}, ntmOption);
# 		ntmLeaveOption["hitType"] = "event";
# 		ntmLeaveOption["eventCategory"] = "action";
# 		ntmLeaveOption["eventAction"] = "leave";
#
# 		if (/\/article\/comment\//.test(location.href) == false && $("#contents").length > 0) {
# 			if (window.addEventListener) {
# 				window.addEventListener("load", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				}, false);
# 				window.addEventListener("onpagehide" in window ? "pagehide" : "beforeunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				}, false);
# 			} else if (window.attachEvent) {
# 				window.attachEvent("onload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				});
# 				window.attachEvent("onpagehide" in window ? "onpagehide" : "onbeforeunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				});
# 			} else {
# 				var onUnloadEventName = "onpagehide" in window ? "onpagehide" : "onbeforeunload";
# 				var fnOnUnload = window[onUnloadEventName];
# 				window[onUnloadEventName] = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 					if (fnOnUnload) {
# 						fnOnUnload();
# 					}
# 				};
#
# 				var fnOnload = window.onload;
# 				window.onload = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 					if (fnOnload) {
# 						fnOnload();
# 					}
# 				};
# 			}
# 		}
# 	}
# </script>
# </div>
# <script>
# 			var eventType = "onpageshow" in window ? "pageshow" : "load";
# 			$(window).on(eventType, function() {
# 				window.ntm = window.ntm || [];
#
# 				var pageviewInfo = {
# 					event: "nLogPageViewService",
# 					nlogEvt: {
# 						page_layout: window.layoutName
# 					}
# 				};
#
# 				pageviewInfo.nLogPageviewSti = "news";
#
# 				window.ntm.push(pageviewInfo);
#
# 				// ma 로그 전송
# 				var data = {
# 					"service": "news",
# 					"baseInfo": {
# 						"category": "섹션홈"
# 					},
# 					"extraInfo": {
# 						"sectionId": "100"
# 					}
# 				};
#
# 				if (typeof ma !== "undefined") {
# 					ma.init({
# 						api: "https://ma.news.naver.com/l",
# 						data: data
# 					});
# 				}
#
# 				if (window.matchMedia("(prefers-color-scheme)").media === "not all") {
# 					$("html").removeClass("DARK_THEME");
# 				}
#
# 				setTimeout(function() {
# 					$("._OPACITY_FADE_TO").fadeTo(50, 1);
# 				}, 3000);
# 			});
# 		</script>
# </body>
# </html>
#
# 46
# 46
# 1 국회, 김상환 헌재소장 임명동의안 가결…찬성 206표·반대 49표 : https://n.news.naver.com/mnews/article/277/0005626928
# 2 아들과 함께 임명장 받은 정은경·김영훈 장관 [이런뉴스] : https://n.news.naver.com/mnews/article/056/0011994600
# 3 강선우 여진 계속...인사처장 "TV 없어 갑질 논란 몰라" : https://n.news.naver.com/mnews/article/052/0002222944
# 4 金총리 “경주 APEC, 지난 정부서 준비 미진…성공 미지수” : https://n.news.naver.com/mnews/article/020/0003649845
# 5 김상욱 "강선우, 국민수용성 과락…결자해지의 심정으로 직접 나서야" : https://n.news.naver.com/mnews/article/448/0000544432
# 6 "'개딸·나라 망하는 길'…극우 유튜버 흉내" 박주민, 오세훈 비판 : https://n.news.naver.com/mnews/article/437/0000449736
# 7 여야, 국힘 몫 인권위원 선출안 본회의 상정 보류 : https://n.news.naver.com/mnews/article/016/0002503693
# 8 국힘 조경태, 혁신파 후보 단일화 제안‥"내란당 치욕 벗어나야" : https://n.news.naver.com/mnews/article/214/0001438218
# 9 野 "강선우 청문회 하루 더 하자" 민주당에 공식 제안 : https://n.news.naver.com/mnews/article/656/0000141246
# 10 대통령실, 이진숙 여름휴가 신청 반려…"재난 상황서 부적절" : https://n.news.naver.com/mnews/article/001/0015523201
# 11 [속보]“아프지만 누군가 말해야” 박찬대도 강선우 사퇴 요청 : https://n.news.naver.com/mnews/article/021/0002724748
# 12 "금융위 해체 확실히 말해야.. 정부 망설임, 모피아 로비 의심" : https://n.news.naver.com/mnews/article/047/0002482070
# 13 권칠승, ‘의원과 보좌진은 동지’ 발언 논란에 “전혀 경우에 맞지 않아” : https://n.news.naver.com/mnews/article/032/0003384818
# 14 [인터뷰]박찬대 "자사주 소각법 9월 처리…쪼개기 상장 추가대책" : https://n.news.naver.com/mnews/article/014/0005381397
# 15 ‘비번+얼굴인식’ 꽁꽁 잠궈논 尹 아이폰...“안 알려 줄 것” : https://n.news.naver.com/mnews/article/018/0006072278
# 16 김성태 한탄 "전한길의 '놀이터' 된 당…이 비대위가 무슨 놈의 비대위인지 납득 안가" : https://n.news.naver.com/mnews/article/002/0002398452
# 17 위성락, ‘74시간 패키지 딜’ 마치고 내일 귀국…관세협상 분수령 : https://n.news.naver.com/mnews/article/005/0001791509
# 18 국회, 김상환 헌재소장 임명동의안 가결…찬성 206표·반대 49표 : https://n.news.naver.com/mnews/article/277/0005626928
# 19 [단독]사우디 호위함 사업에 무슨 일?…수출 '원팀' 합의 깨질판 : https://n.news.naver.com/mnews/article/018/0006072237
# 20 여, '강선우 엄호' 유지…야 "청문회 하루 더" : https://n.news.naver.com/mnews/article/422/0000762992
# 21 與 "검찰 억지 기소 바로 잡을 것…불법 수사·기소 발견시 감찰 요구" : https://n.news.naver.com/mnews/article/008/0005225807
# 22 민주당, ‘강선우 추가 청문회’ 제안에 “대통령 결단만 남아” : https://n.news.naver.com/mnews/article/056/0011994681
# 23 국힘 "李, 야당일 땐 대통령 책임.. 이젠 국힘 지자체장 책임? 비겁하다" : https://n.news.naver.com/mnews/article/661/0000058883
# 24 '주진우 방지법' 발의 강득구 "朱 국힘대표 출마? 소가 웃어…자숙도 부족할 판에" : https://n.news.naver.com/mnews/article/421/0008387902
# 25 [맞수다] "임명 반대가 2배, 강선우 도대체 왜?"‥"전한길 입당, 극우 대침공" : https://n.news.naver.com/mnews/article/214/0001438276
# 26 “작전 성공”…무려 ‘29박 30일’ 포상 휴가 받은 병사들, 왜? : https://n.news.naver.com/mnews/article/016/0002503913
# 27 李대통령, 장관 8명에 임명장…"공무원이 열심히해야 국민이 편해" : https://n.news.naver.com/mnews/article/448/0000544543
# 28 강선우 임명 강행 수순 '후폭풍'…李대통령 깊어지는 고심 : https://n.news.naver.com/mnews/article/030/0003334488
# 29 李대통령, 신임장관에 임명장…"공무원이 열심히해야 국민 편해"(종합) : https://n.news.naver.com/mnews/article/001/0015525037
# 30 "대법도 핫한 놈 쉽게 못 죽여" 이 말로 '李 책사' 김우영 탄생 [이재명의 사람들⑭] : https://n.news.naver.com/mnews/article/025/0003457103
# 31 수해로 난리인데 휴가?...한준호 "이진숙, 사의 표명하고 쭉 쉬어라" [앵커리포트] : https://n.news.naver.com/mnews/article/052/0002223375
# 32 “대만해협·한반도 전쟁 동시 발발시 美 핵확장억제 작동 불투명…핵확장억제 맹목적 신뢰는 위험한 도박” : https://n.news.naver.com/mnews/article/021/0002724731
# 33 김상욱 “강선우, 국민 수용성 측면서 과락…합격 힘들어” : https://n.news.naver.com/mnews/article/009/0005529834
# 34 '8월 사임론' 불거진 이시바…李 대통령 '8·15 경축사' 고심 깊어질 듯 : https://n.news.naver.com/mnews/article/421/0008387798
# 35 인사혁신처장, "문재인 인사 '멍청', 박원순 시장 '깨끗'" 과거 발언 논란 [앵커리포트] : https://n.news.naver.com/mnews/article/052/0002223365
# 36 국힘 혁신위, 또 '빈손 좌초' 수순...윤희숙 "안불렀는데 어떻게 가나" : https://n.news.naver.com/mnews/article/123/0002364315
# 37 "강선우 관련 질문 안 했으면 좋겠다"…완강한 민주당 : https://n.news.naver.com/mnews/article/015/0005161662
# 38 국힘, 의총서 혁신안 결론 못내…"윤희숙 직접 설명한 뒤 논의해야"(종합) : https://n.news.naver.com/mnews/article/003/0013380222
# 39 수사·기소 분리, 특사경은 어디로 가야 하나 : https://n.news.naver.com/mnews/article/047/0002482057
# 40 김한규 "강선우, 당내에서도 문제 있다고 봐…진솔한 입장 표명 필요" : https://n.news.naver.com/mnews/article/277/0005626892
# 41 국힘 "강선우, 대학 교수 시절 5주 무단결강…갑질은 고질병" : https://n.news.naver.com/mnews/article/025/0003457095
# 42 與, 검찰 조작 기소 총공세…"정치검찰 만행 발본색원" : https://n.news.naver.com/mnews/article/277/0005626888
# 43 김도읍 ‘해양수산 기능 통합’ 신설 법안 발의…해수부 확대 개편 ‘탄력’ : https://n.news.naver.com/mnews/article/082/0001336829
# 44 "만회할 기회를" "재고해야"…'강선우 엄호' 택한 민주당, 복잡한 속내 : https://n.news.naver.com/mnews/article/008/0005225761
# 45 '맹추격' 박찬대 역전 고심...'통합경선' 변수 될까? : https://n.news.naver.com/mnews/article/052/0002223349
# 46 "안 불렀다" vs "본인이 답 안해"…윤희숙-지도부 '진실게임' : https://n.news.naver.com/mnews/article/008/0005225743

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

req_header = {
    
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36",
    'referer' : 'https://comic.naver.com/webtoon/detail?titleId=641253&no=557&week=fri'

}

img_urls = [
    'https://image-comic.pstatic.net/webtoon/641253/557/20250530180433_b2d3f6f740c3326539190c705281803e_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/641253/557/20250530180433_b2d3f6f740c3326539190c705281803e_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/641253/557/20250530180433_b2d3f6f740c3326539190c705281803e_IMAG01_3.jpg'

]

for img_url in img_urls:
    # requests 의 get(url, headers) 함수 호출하기 
    res = requests.get(img_url, headers = req_header)
    print(res.ok, res.status_code)
    if res.ok:
        # binary 응답 데이터 가져오기
        img_data = res.content
        #print(img_data)
        # url에서 파일명만 추출하기
        file_name = os.path.basename(img_url)
        # binday data를 file에 write하기
        with open(file_name, 'wb') as file:
            print(f'Writing to {file_name}({len(img_data):,}bytes)')
            file.write(img_data)
# Out:
# True 200
# Writing to 20250530180433_b2d3f6f740c3326539190c705281803e_IMAG01_1.jpg(109,231bytes)
# True 200
# Writing to 20250530180433_b2d3f6f740c3326539190c705281803e_IMAG01_2.jpg(166,886bytes)
# True 200
# Writing to 20250530180433_b2d3f6f740c3326539190c705281803e_IMAG01_3.jpg(74,294bytes)

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %%
import requests
from bs4 import BeautifulSoup
import os

webtoon_url = 'https://comic.naver.com/webtoon/detail?titleId=641253&no=557&week=fri'

req_header = {
    
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36",
    'referer' : webtoon_url

}

res = requests.get(webtoon_url)
print(res.status_code)

if res.ok:
    soup = BeautifulSoup(res.text, 'html.parser')
    print(len(soup.select("img[src *= 'IMAG01']")))
    #img src file명을 저장할 list 선언
    img_url_list = list()
    
    img_tags = soup.select("img[src *= 'IMAG01']") #Resultset type [Tag, Tag, Tag]
    for img_tag in img_tags: #Tag <img>
        img_url = img_tag["src"]
        img_url_list.append(img_url)
        #print(img_url)
    #print(len(img_url_list), img_url_list[0:2])
    
    #img 디렉토리가 없으면 생성하기
    imgdir_name = 'img'
    if not os.path.isdir(imgdir_name):
        os.mkdir(imgdir_name)

    for jpg_url in img_url_list:
        res = requests.get(jpg_url, headers = req_header)
        if res.ok:
            img_data = res.content
            dir_name = os.path.join(imgdir_name, os.path.basename(jpg_url))
            #print(dir_name)
            # binday data를 file에 write하기
            with open(dir_name, 'wb') as file:
                print(f'Writing to {dir_name}({len(img_data):,}bytes)')
                file.write(img_data)
            
        else:
            print(f"Error Code = {res.status_code}")

# %% [markdown]
# 리팩토링 한 코드

# %%
import requests
from bs4 import BeautifulSoup
import os

# 기본 설정
url = 'https://comic.naver.com/webtoon/detail?titleId=833255&no=35&week=tue'
req_header = {'referer': url}
imgdir_name = 'img'

# 이미지 저장 폴더가 없으면 생성
os.makedirs(imgdir_name, exist_ok=True)

# 웹 페이지 요청 및 확인
res = requests.get(url)
if not res.ok:
    print(f'Error Code = {res.status_code}')
    exit()

# 이미지 URL 추출
soup = BeautifulSoup(res.text, 'html.parser')
img_url_list = [img_tag['src'] for img_tag in soup.select("img[src*='IMAG01']")]

# 이미지 다운로드
for img_url in img_url_list:
    res = requests.get(img_url, headers=req_header)
    if res.ok:
        img_data = res.content
        file_path = os.path.join(imgdir_name, os.path.basename(img_url))
        with open(file_path, 'wb') as file:
            print(f'Writing to {file_path} ({len(img_data):,} bytes)')
            file.write(img_data)
    else:
        print(f'Error Code = {res.status_code} for {img_url}')

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_files = {
    'img1' : open('f1.jpg','rb'),
    'img2' : open('f2.jpg','rb')
}
#print(upload_files)

url = 'http://httpbin.org/post'
# file 업로드 하려면 requests의 post 함수에 files 속성을 사용합니다.

res = requests.post(url, files = upload_files)
print(res.status_code)
print(type(res.json()))
print(res.json())
# Out:
# 200
# <class 'dict'>
# {'args': {}, 'data': '', 'files': {'img1': 'data:application/octet-stream;base64,...', 'img2': 'data:application/octet-stream;base64,...'}, 'form': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Content-Length': '183771', 'Content-Type': 'multipart/form-data; boundary=87ec62bb6818f80adaf5a45ec98c642e', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.32.3', 'X-Amzn-Trace-Id': 'Root=1-68804514-42761ef47cb5be2d2e4809cd'}, 'json': None, 'origin': '58.122.113.42', 'url': 'http://httpbin.org/post'}

# %% [markdown]
# ### 4. 캡챠(이미지) API 호출하기
# * urllib 사용
# * 1. 캡차 키 발급 요청
#   2. 캡차 이미지 요청
#   3. 사용자 입력값 검증 요청

# %%
# 캡차 키 발급 요청
import os
import sys
import urllib.request
client_id = "1nBHeL5LELxCoTGkDklR" # 개발자센터에서 발급받은 Client ID 값
client_secret = "PqxqnSjgzF" # 개발자센터에서 발급받은 Client Secret 값
code = "0"
url = "https://openapi.naver.com/v1/captcha/nkey?code=" + code
#Request 객체 생성
request = urllib.request.Request(url)
#요청 헤더
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
#서버에 request 전달
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"key":"1UCfad5fZxVoJReF"}

# %%
# 캡차 이미지 요청
import urllib.request
client_id = "1nBHeL5LELxCoTGkDklR" # 개발자센터에서 발급받은 Client ID 값
client_secret = "PqxqnSjgzF" # 개발자센터에서 발급받은 Client Secret 값
key = "1UCfad5fZxVoJReF" # 캡차 Key 값
url = "https://openapi.naver.com/v1/captcha/ncaptcha.bin?key=" + key
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    print("캡차 이미지 저장")
    response_body = response.read()
    with open('captcha.jpg', 'wb') as f:
        f.write(response_body)
else:
    print("Error Code:" + rescode)
# Out:
# 캡차 이미지 저장

# %%
#  사용자 입력값 검증 요청
import urllib.request
client_id = "1nBHeL5LELxCoTGkDklR" # 개발자센터에서 발급받은 Client ID 값
client_secret = "PqxqnSjgzF" # 개발자센터에서 발급받은 Client Secret 값
code = "1"
key = "1UCfad5fZxVoJReF"
value = "98BK2"
url = "https://openapi.naver.com/v1/captcha/nkey?code=" + code + "&key=" + key + "&value=" + value
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"result":true,"responseTime":79.42}

# %% [markdown]
# * requests를 사용하는 코드로 변경하기
# * [requests docs](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
# 사용자 입력값 검증 요청
import os
from dotenv import load_dotenv
import requests

# .env 파일에서 환경 변수 로드
load_dotenv()

# 환경 변수에서 값 읽기
client_id = os.getenv("NAVER_CLIENT_ID")  # .env 파일의 NAVER_CLIENT_ID
client_secret = os.getenv("NAVER_CLIENT_SECRET")  # .env 파일의 NAVER_CLIENT_SECRET
key = "1UCfad5fZxVoJReF"
#os.getenv("NAVER_CAPTCHA_KEY")  # .env 파일의 NAVER_CAPTCHA_KEY

# 사용자 입력값
code = "1"
value = "98BK2"  # 실제 사용시 사용자 입력값으로 대체 필요

# URL 구성
# query string key1=value1&key2=value2
url = f"https://openapi.naver.com/v1/captcha/nkey?code={code}&key={key}&value={value}"

# 요청 헤더
headers = {
    "X-Naver-Client-Id": client_id,
    "X-Naver-Client-Secret": client_secret
}

# 요청 보내기
try:
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # 4xx, 5xx 오류 발생시 예외 발생
    
    # 응답 처리
    print(response.text)
    
except requests.exceptions.RequestException as e:
    print(f"Error occurred: {e}")
    print(f"Status Code: {response.status_code if 'response' in locals() else 'N/A'}")
# Out:
# {"result":true,"responseTime":473.7}

# %% [markdown]
# ### 5. 블로그 검색하기

# %%
import requests
from pprint import pprint
import os
from dotenv import load_dotenv

# .env 파일에서 환경 변수 로드
load_dotenv()

# 환경 변수에서 값 읽기
client_id = os.getenv("NAVER_CLIENT_ID")  # .env 파일의 NAVER_CLIENT_ID
client_secret = os.getenv("NAVER_CLIENT_SECRET")  # .env 파일의 NAVER_CLIENT_SECRET

headers = {
    'X-Naver-Client-Id': client_id,
    'X-Naver-Client-Secret': client_secret,
}

# query string 문자열을 dict 선언
payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json' #?query=파이썬&display=100&sort=sim

# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)
# json() 함수로 응답 결과 가져오기
items_data = res.json()["items"]
print(type(res.json()))
#pprint(res.json())
print(len(items_data), type(items_data), type(items_data[0]))
pprint(items_data[0])

#print(type(res.json()))
#print(len(items_data), type(items_data), type(items_data[0]))
#[{},{},{}] 
# [] - 100 개의 데이터, {title:'',link:''} - 1개의 블로그 글 데이터

# %%
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'
items_list = list()
item_list = []
for item in items_data:
#     print(item)
    item_list.append(item['title'])
    item_list.append(item['bloggername'])
    item_list.append(item['description'])
    item_list.append(item['bloggerlink'])
    item_list.append(item['link'])
    item_list.append(item['postdate'])

    items_list.append(item_list)
    item_list = []

print(items_list) #[[],[]]

# 'data/nhnblog.txt' 파일 생성하기
with open('data/nhnblog.txt','w',encoding="utf-8")as file:
    for items in items_list:
        for item in items:
            item = item + '\n'
            file.write(item)
        file.write('-'*150+'\n')
# Out:
# [['대전<b>파이썬</b>학원 단계별 코딩 실무 학습 과정', '오롯이 여행, 마음먹기 나름 :)', '그래서 대전<b>파이썬</b>학원을 알아보기로 했죠. 아무 데서나 할 순 없고 커리큘럼을 단계별 실무 위주로... 기초 코딩: 프로그래밍 언어 이 과정은 대전<b>파이썬</b>학원에 처음 오는 입문자들이 프로그래밍 언어를... ', 'blog.naver.com/she_op', 'https://blog.naver.com/she_op/223881011131', '20250528'], ['강남 AI특강, <b>파이썬</b>으로 시작하는 실전 수업', '퍼플피치', '결국 <b>파이썬</b>으로 수렴되더라고요. 문법도 어렵지 않고, 무엇보다 인공지능이나 빅데이터 같은 분야에서 거의 필수처럼 쓰인다고 하니까요. 이 강의의 커리큘럼을 살펴봤을 때 <b>파이썬</b> 중심으로 구성되어 있다는... ', 'blog.naver.com/purplepeach81', 'https://blog.naver.com/purplepeach81/223902982714', '20250618'], ['<b>파이썬</b>으로 주식 분석', '해머', '<b>파이썬</b>으로 주식 분석을 해보고 싶은 분들 제가 <b>파이썬</b>을 사용해서 주식 데이터를 수집하고 분석해본 경험을 바탕으로 정리해볼게요. 초보자도 이해할 수 있도록 전체적인 흐름부터 사용한 라이브러리... ', 'blog.naver.com/sn525v', 'https://blog.naver.com/sn525v/223924507846', '20250709'], ['대전<b>파이썬</b>학원 실전에 적용 가능한 실무 수업', '▶ 제이의 맛있는 세상 ◀', '되면서 <b>파이썬</b>과 같은 언어를 기반으로 한 학습의 필요성이 더욱 커지고 있답니다. 이러한 흐름 속에서 기초부터 실무 활용까지 단계적으로 학습할 수 있는 곳을 찾는다면 대전<b>파이썬</b>학원이 좋은 선택이 될 수... ', 'blog.naver.com/xshinerx', 'https://blog.naver.com/xshinerx/223920684811', '20250704'], ['<b>파이썬</b>전문가 자격증 종류 및 효율적인 취득방법', '멜잉로그 : 현 영어강사 블로그', '<b>파이썬</b>전문가 자격증 종류 및 효율적인 취득방법 <b>파이썬</b>은 요즘 다양한 분야에서 널리 사용되는 프로그래밍 언어로, 데이터 분석, 웹 개발, 인공지능 등에서 중요한 역할을 하고 있습니다. 저는 원래... ', 'blog.naver.com/mellybird', 'https://blog.naver.com/mellybird/223842981098', '20250422'], ['빅데이터분석기사 <b>파이썬</b> 시험 공부방법 합격후기', '묘한 교육 연구소', '빅데이터분석기사 <b>파이썬</b> 시험 공부방법 합격후기 빅데이터분석기사 <b>파이썬</b> 시험 공부방법 합격후기 빅데이터분석기사 <b>파이썬</b> 시험 공부방법 합격후기 빅데이터분석기사 취득자의 후기를 소개합니다.... ', 'blog.naver.com/blackhole_chinese', 'https://blog.naver.com/blackhole_chinese/223900117182', '20250615'], ['<b>파이썬</b>전문가 자격증 학습방법 취득후기', 'ALICEMADE-앨리스가 만들어가는 세상', '<b>파이썬</b>전문가 자격증 학습방법 취득후기 요즘 IT 분야에 대한 관심이 점점 더 높아지며 앞으로 어떤... 그러던 중 남들에게 제가 알고 있는 기술을 알려주고 싶은 마음에 <b>파이썬</b>전문가 자격증에 도전했고 나만의... ', 'blog.naver.com/bbobbny', 'https://blog.naver.com/bbobbny/223842932148', '20250422'], ['<b>파이썬</b>자격증 종류 취업 분야 및 공부 후기', '세 아이와 함께 성장하는 곳', '<b>파이썬</b>자격증 종류 취업 분야 및 공부 후기 공부하신 분의 후기를 바탕으로 작성되었음을... 결심하고 처음으로 도전한 것은 <b>파이썬</b>자격증이었어요. 입문용 언어라 가장 저에게 적합했는데요. 같은... ', 'blog.naver.com/kang6902', 'https://blog.naver.com/kang6902/223863482199', '20250512'], ['macOS <b>파이썬</b> 프로그래밍 PYTHON 개발 환경 구축 방법', '짜루의 이것저것 리뷰', 'macOS <b>파이썬</b> 프로그래밍 PYTHON 개발 환경 구축 방법 요즘 AI 자동화가 대세다. n8n 같은 AI 기반 워크플로 자동화 도구만으로도 충분하지만, <b>파이썬</b> 프로그래밍까지 더해진다면 훨씬 더 강력해진다.... ', 'blog.naver.com/skdaksdptn', 'https://blog.naver.com/skdaksdptn/223932219095', '20250713'], ['<b>파이썬</b>전문가 자격증 종류 체계적인 취득방법 및 학습과정', '하영목(출간작가)의 블로그', '<b>파이썬</b>전문가 자격증 종류 체계적인 취득방법 및 학습과정 요즘은 취업하려면 코딩은 필수인 거... 오늘 <b>파이썬</b>전문가 자격증 종류 체계적인 취득방법 및 학습과정을 가져와 보았습니다! <b>파이썬</b> 자격증 종류... ', 'blog.naver.com/career4ukr', 'https://blog.naver.com/career4ukr/223842923010', '20250422'], ['<b>파이썬</b>학원, 전공 대비 여름방학 특강', '지혜를 여는 부엉이상점', "그런데 요즘은 '<b>파이썬</b>'이 대세라는데요 <b>파이썬</b>은 왜 전공자에게 필수 언어가 되었을까? 프로그래밍 언어는 수업이 많지만, 최근 몇 년 사이 전공자들이 입을 모아 &quot;<b>파이썬</b>은 무조건 해둬야 해&quot;라고 말하는... ", 'blog.naver.com/smgong00', 'https://blog.naver.com/smgong00/223903445166', '20250618'], ['[<b>파이썬</b> 배우기] 직장인 일잘러... 시작한 <b>파이썬</b> 독학하기... ', '싱글맘 바니의 스토리 블로그', "<b>파이썬</b>, <b>파이썬</b>... 우연히 들은 CHAT GPT 강의에서 업무 자동화 프로세스 라는 단어가 내 귀에 딱 꽂혔다. 나는 매일 출근하며 영업일을 보는 직장인이라 고객사들에게 늘 전화가 온다. '이 제품은 단가가 얼마?... ", 'blog.naver.com/singlemom_bonnie', 'https://blog.naver.com/singlemom_bonnie/223911004817', '20250625'], ['<b>파이썬</b> 기초 독학 - 이 책으로 비전공자도 가능', '˚✧₊❁⁎솨의봄날⁎⁺˳❁✧༚', '최근에 제가 AI관련 공부를 시작하게 되었는데요 거기서 나오는게 <b>파이썬</b>이더라구요 <b>파이썬</b> AI와 코딩의 가장 기초가 되더라구요 코딩, 어렵고 복잡한 언어라고만 생각했던 그 시절 그런데 요즘은 일상 속에서... ', 'blog.naver.com/sohwa91', 'https://blog.naver.com/sohwa91/223904016899', '20250618'], ['AI 인공지능 프로젝트 <b>파이썬</b> 프로젝트 입문자를 위한 책 추천', '엔돌슨의 IT이야기', '카테고리 없음 AI 인공지능 프로젝트 <b>파이썬</b> 프로젝트 입문자를 위한 책 추천 by 엔돌슨 2025. 6. 13. AI 인공지능 프로젝트 <b>파이썬</b> 프로젝트 입문자를 위한 책 추천 AI와 프로그래밍이 더 이상 전문가만의... ', 'https://ndolson.com/', 'https://ndolson.com/531581', '20250613'], ['<b>파이썬</b> 자격증 시험 종류 및 취득과정', '화닝의 일본어+교육 교실', '오늘은 <b>파이썬</b> 자격증 시험 종류 및 취득과정에 대해서 자세 ...
